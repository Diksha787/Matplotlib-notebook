# %% [markdown]
# # Ploting Histograms

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
#write the above code here

# %%
ml_students_age = np.random.randint(18,45, (100))   # range between 18 and 45 total number of students is 100
py_students_age = np.random.randint(15,40, (100))

# %%
#write the above code here

# %%
print(ml_students_age)
print(py_students_age)
# Out:
# [42 43 24 31 31 24 40 28 40 41 21 34 41 27 34 19 41 30 39 24 28 39 41 20
#  40 21 20 19 35 39 26 20 35 23 39 43 23 32 37 41 43 44 20 34 23 21 18 39
#  29 20 32 22 34 31 21 24 29 40 22 29 22 23 21 29 28 39 21 18 30 22 38 20
#  20 35 23 43 26 30 34 43 28 32 24 33 28 41 41 36 34 34 35 44 38 33 33 42
#  19 33 40 26]
# [29 17 26 37 29 28 20 34 22 38 24 16 17 30 38 28 30 21 29 36 19 18 18 25
#  20 37 18 34 35 26 29 23 35 22 31 30 23 16 36 35 38 21 17 18 18 33 20 30
#  38 24 19 30 24 36 20 28 38 20 22 15 37 32 25 22 31 17 25 38 27 32 20 20
#  32 27 34 24 20 17 34 29 31 24 27 25 26 34 15 20 19 32 19 28 21 18 33 16
#  21 33 22 24]

# %%
#write the above code here

# %%
plt.hist(ml_students_age)
plt.show()

# %%
#write the above code here

# %%
#very importatn to label a histogram only possible if know what nature of the data histogram takes

# %%
plt.hist(ml_students_age)    #histogram function  

plt.title("ML Students age histograms")
plt.xlabel("Students age cotegory")
plt.ylabel("No. Students age")
plt.show()

# %%
#write the above code here

# %%
#observation in the x axis it has taken classes of ages and in the y axis what is the frequency which falls in that particular
#classs

# %%
"""
plt.hist(
    x,
    bins=None,
    range=None,
    density=None,
    weights=None,
    cumulative=False,
    bottom=None,
    histtype='bar',
    align='mid',
    orientation='vertical',
    rwidth=None,
    log=False,
    color=None,
    label=None,
    stacked=False,
    normed=None,
    *,
    data=None,
    **kwargs,
)

x, or format []
bins=None or sequence
histtype : {'bar', 'barstacked', 'step',  'stepfilled'}
align : {'left', 'mid', 'right'}
orientation : {'horizontal', 'vertical'}
rwidth : scalar or None
color : color or format []
label : str or format []
"""
# Out:
# "\nplt.hist(\n    x,\n    bins=None,\n    range=None,\n    density=None,\n    weights=None,\n    cumulative=False,\n    bottom=None,\n    histtype='bar',\n    align='mid',\n    orientation='vertical',\n    rwidth=None,\n    log=False,\n    color=None,\n    label=None,\n    stacked=False,\n    normed=None,\n    *,\n    data=None,\n    **kwargs,\n)\n\nx, or format []\nbins=None or sequence\nhisttype : {'bar', 'barstacked', 'step',  'stepfilled'}\nalign : {'left', 'mid', 'right'}\norientation : {'horizontal', 'vertical'}\nrwidth : scalar or None\ncolor : color or format []\nlabel : str or format []\n"

# %%
bins = [15,20,25,30,35,40,45] #bins devide the classes
#plt.figure(figsize = (16,9))   


plt.hist(ml_students_age, bins, rwidth=0.8, histtype = "step",     #step no color inside
         orientation='vertical', color = "m", label = "ML Student")   #Label will not show untill we use the legend function

plt.title("ML Students age histograms")
plt.xlabel("Students age cotegory")
plt.ylabel("No. Students age")
#plt.legend()         #this legend depends on label in plot
plt.show()

# %%
#write the above code here

# %%
from matplotlib import style
style.use("ggplot")
bins = [15,20,25,30,35,40,45] #bins devide the classes
#plt.figure(figsize = (16,9))   


plt.hist(ml_students_age, bins, rwidth=0.8, histtype = "bar",  #hist type bar returns the bar
         orientation='horizontal', color = "m", label = "ML Student")   #Label will not show untill we use the legend function

plt.title("ML Students age histograms")
plt.xlabel("Students age cotegory")
plt.ylabel("No. Students age")
plt.legend()         #this legend depends on label in plot
plt.show()

# %%
#write the above code here

# %%
from matplotlib import style
style.use("ggplot")
bins = [15,20,25,30,35,40,45] #bins devide the classes
#plt.figure(figsize = (16,9))   


plt.hist(ml_students_age, bins, rwidth=0.8, histtype = "bar",align = "left",  #hist type bar returns the bar
         orientation='vertical', color = "m", label = "ML Student")   #Label will not show untill we use the legend function

plt.title("ML Students age histograms")
plt.xlabel("Students age cotegory")
plt.ylabel("No. Students age")
plt.legend()         #this legend depends on label in plot
plt.show()

# %%
#bins= devide your classes bydefault bins has been taken meaning the classes has been created in the x axis
#rwidth= our bars have occupied 100 percent width lets change the percentage of it 
#histType =  let us give step as value and see the darkness has been removed or the shade has been removed
#Allign = tells us where our bar should be middle left or right
#Orientation = we can make the bar left or right
##Label will not show untill we use the legend function

# %%
#write the above code here

# %%
from matplotlib import style
style.use("ggplot") #background
plt.figure(figsize = (5,4)) #increase the size of the entire graph width,height in inches

plt.hist(ml_students_age, bins, rwidth=0.8, histtype = "bar",
          orientation='vertical', color ="r" , label = "ML Student")                                                    

plt.hist(py_students_age, bins, rwidth=0.8, histtype = "bar",
        orientation='vertical', color = "y", label = "Py Student")

plt.title("ML & Py Students age histograms")
plt.xlabel("Students age cotegory")
plt.ylabel("No. Students age")
plt.legend()           #use loc to set the position
plt.show()

# %%
#write the above code here

# %%
from matplotlib import style
style.use("ggplot") #background
plt.figure(figsize = (5,4)) #increase the size of the entire graph width,height in inches

plt.hist(ml_students_age, bins, rwidth=0.8, histtype = "bar",
          orientation='vertical', color ="r" , label = "ML Student")                                                    

plt.hist(py_students_age, bins, rwidth=0.8, histtype = "bar",
        orientation='vertical', color = "y", label = "Py Student")

plt.title("ML & Py Students age histograms")
plt.xlabel("Students age cotegory")
plt.ylabel("No. Students age")
plt.legend()
plt.show()

# %%
#write the above code here

# %%
from matplotlib import style
style.use("ggplot") #background
plt.figure(figsize = (10,7)) #increase the size of the entire picture or graph

plt.hist(ml_students_age, bins, rwidth=0.8, histtype = "bar",
          orientation='vertical', color ="r" , label = "ML Student")                                                    

#plt.hist(py_students_age, bins, rwidth=0.8, histtype = "bar",
        #orientation='vertical', color = "y", label = "Py Student")

plt.title("ML & Py Students age histograms")
plt.xlabel("Students age cotegory")
plt.ylabel("No. Students age")
plt.legend()
plt.show()

# %%
#write the above code here

# %%
from matplotlib import style
style.use("ggplot")   #backround 
plt.figure(figsize = (10,7))

plt.hist([ml_students_age,py_students_age], bins, rwidth=0.7, histtype = "bar",
          orientation='vertical', color =["y","r"] , label = ["ML Student", "Py Student"])

#plt.hist(py_students_age, bins, rwidth=0.8, histtype = "bar",
        #orientation='vertical', color = "y", label = "Py Student")

plt.title("ML & Py Students age histograms")
plt.xlabel("Students age cotegory")
plt.ylabel("No. Students age")
plt.legend()
plt.show()

# %%
#write the above code here

# %%
bins = [15,20,25,30,35,40,45]
plt.figure(figsize = (16,9))   


plt.hist(ml_students_age, bins, rwidth=0.8, histtype = "bar",
         orientation='vertical', color = "m", label = "ML Student")   #Label will not show untill we use the legend function

plt.title("ML Students age histograms")
plt.xlabel("Students age cotegory")
plt.ylabel("No. Students age")
plt.legend()         #this legend depends on label in plot
plt.show()

# %%
#write the above code here#write the above code here
